# %%
'''Neural style transfer with Keras.

Run the script with:
```
python neural_style_transfer.py path_to_your_base_image.jpg path_to_your_reference.jpg prefix_for_results
```
e.g.:
```
python neural_style_transfer.py img/tuebingen.jpg img/starry_night.jpg results/my_result
```
Optional parameters:
```
--iter, To specify the number of iterations the style transfer takes place (Default is 10)
--content_weight, The weight given to the content loss (Default is 0.025)
--style_weight, The weight given to the style loss (Default is 1.0)
--tv_weight, The weight given to the total variation loss (Default is 1.0)
```

It is preferable to run this script on GPU, for speed.

Example result: https://twitter.com/fchollet/status/686631033085677568

# Details

Style transfer consists in generating an image
with the same "content" as a base image, but with the
"style" of a different picture (typically artistic).

This is achieved through the optimization of a loss function
that has 3 components: "style loss", "content loss",
and "total variation loss":

- The total variation loss imposes local spatial continuity between
the pixels of the combination image, giving it visual coherence.

- The style loss is where the deep learning keeps in --that one is defined
using a deep convolutional neural network. Precisely, it consists in a sum of
L2 distances between the Gram matrices of the representations of
the base image and the style reference image, extracted from
different layers of a convnet (trained on ImageNet). The general idea
is to capture color/texture information at different spatial
scales (fairly large scales --defined by the depth of the layer considered).

 - The content loss is a L2 distance between the features of the base
image (extracted from a deep layer) and the features of the combination image,
keeping the generated image close enough to the original one.

# References
    - [A Neural Algorithm of Artistic Style](http://arxiv.org/abs/1508.06576)
'''

from __future__ import print_function
from keras.preprocessing.image import load_img, img_to_array, array_to_img # , save_img
import numpy as np
from scipy.optimize import fmin_l_bfgs_b
import time
import argparse

from keras.applications import vgg19
from keras import backend as K

parser = argparse.ArgumentParser(description='Neural style transfer with Keras.')
parser.add_argument('base_image_path', metavar='base', type=str,
                    help='Path to the image to transform.')
parser.add_argument('style_reference_image_path', metavar='ref', type=str,
                    help='Path to the style reference image.')
parser.add_argument('result_prefix', metavar='res_prefix', type=str,
                    help='Prefix for the saved results.')
parser.add_argument('--iter', type=int, default=10, required=False,
                    help='Number of iterations to run.')
parser.add_argument('--content_weight', type=float, default=0.025, required=False,
                    help='Content weight.')
parser.add_argument('--style_weight', type=float, default=1.0, required=False,
                    help='Style weight.')
parser.add_argument('--tv_weight', type=float, default=1.0, required=False,
                    help='Total Variation weight.')

args = parser.parse_args(["images/cat.jpg", "images/monet_800600.jpg",
                         "/tmp/cat_monet", "--iter", "200"])
base_image_path = args.base_image_path
style_reference_image_path = args.style_reference_image_path
result_prefix = args.result_prefix
iterations = args.iter

# these are the weights of the different loss components
total_variation_weight = args.tv_weight
style_weight = args.style_weight
content_weight = args.content_weight

# dimensions of the generated picture.
width, height = load_img(base_image_path).size
img_nrows = 300
img_ncols = int(width * img_nrows / height)
print ("Image size is ==== %d X %d -->  %d X %d " %(width, height, img_nrows, img_ncols))
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Image size is ==== 400 X 300 -->  300 X 400

# %%
# util function to open, resize and format pictures into appropriate tensors


def preprocess_image(image_path):
    img = load_img(image_path, target_size=(img_nrows, img_ncols))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = vgg19.preprocess_input(img)
    return img

# util function to convert a tensor into a valid image


def deprocess_image(x):
    if K.image_data_format() == 'channels_first':
        x = x.reshape((3, img_nrows, img_ncols))
        x = x.transpose((1, 2, 0))
    else:
        x = x.reshape((img_nrows, img_ncols, 3))
    # Remove zero-center by mean pixel
    x[:, :, 0] += 103.939
    x[:, :, 1] += 116.779
    x[:, :, 2] += 123.68
    # 'BGR'->'RGB'
    x = x[:, :, ::-1]
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
# get tensor representations of our images
base_image = K.variable(preprocess_image(base_image_path))
style_reference_image = K.variable(preprocess_image(style_reference_image_path))

# this will contain our generated image
if K.image_data_format() == 'channels_first':
    combination_image = K.placeholder((1, 3, img_nrows, img_ncols))
else:
    combination_image = K.placeholder((1, img_nrows, img_ncols, 3))

# combine the 3 images into a single Keras tensor
input_tensor = K.concatenate([base_image,
                              style_reference_image,
                              combination_image], axis=0)

# build the VGG16 network with our 3 images as input
# the model will be loaded with pre-trained ImageNet weights
model = vgg19.VGG19(input_tensor=input_tensor,
                    weights='imagenet', include_top=False)
print('Model loaded.')

# get the symbolic outputs of each "key" layer (we gave them unique names).
outputs_dict = dict([(layer.name, layer.output) for layer in model.layers])

# compute the neural style loss
# first we need to define 4 util functions
# Out:
# Model loaded.

# %%
# the gram matrix of an image tensor (feature-wise outer product)


def gram_matrix(x):
    assert K.ndim(x) == 3
    if K.image_data_format() == 'channels_first':
        features = K.batch_flatten(x)
    else:
        features = K.batch_flatten(K.permute_dimensions(x, (2, 0, 1)))
    gram = K.dot(features, K.transpose(features))
    return gram

# the "style loss" is designed to maintain
# the style of the reference image in the generated image.
# It is based on the gram matrices (which capture style) of
# feature maps from the style reference image
# and from the generated image


def style_loss(style, combination):
    assert K.ndim(style) == 3
    assert K.ndim(combination) == 3
    S = gram_matrix(style)
    C = gram_matrix(combination)
    channels = 3
    size = img_nrows * img_ncols
    return K.sum(K.square(S - C)) / (4. * (channels ** 2) * (size ** 2))

# an auxiliary loss function
# designed to maintain the "content" of the
# base image in the generated image


def content_loss(base, combination):
    return K.sum(K.square(combination - base))

# %%
# the 3rd loss function, total variation loss,
# designed to keep the generated image locally coherent


def total_variation_loss(x):
    assert K.ndim(x) == 4
    if K.image_data_format() == 'channels_first':
        a = K.square(x[:, :, :img_nrows - 1, :img_ncols - 1] - x[:, :, 1:, :img_ncols - 1])
        b = K.square(x[:, :, :img_nrows - 1, :img_ncols - 1] - x[:, :, :img_nrows - 1, 1:])
    else:
        a = K.square(x[:, :img_nrows - 1, :img_ncols - 1, :] - x[:, 1:, :img_ncols - 1, :])
        b = K.square(x[:, :img_nrows - 1, :img_ncols - 1, :] - x[:, :img_nrows - 1, 1:, :])
    return K.sum(K.pow(a + b, 1.25))

# combine these loss functions into a single scalar
loss = K.variable(0.)
layer_features = outputs_dict['block5_conv2']
base_image_features = layer_features[0, :, :, :]
combination_features = layer_features[2, :, :, :]
loss += content_weight * content_loss(base_image_features,
                                      combination_features)

feature_layers = ['block1_conv1', 'block2_conv1',
                  'block3_conv1', 'block4_conv1',
                  'block5_conv1']
for layer_name in feature_layers:
    layer_features = outputs_dict[layer_name]
    style_reference_features = layer_features[1, :, :, :]
    combination_features = layer_features[2, :, :, :]
    sl = style_loss(style_reference_features, combination_features)
    loss += (style_weight / len(feature_layers)) * sl
loss += total_variation_weight * total_variation_loss(combination_image)

# get the gradients of the generated image wrt the loss
grads = K.gradients(loss, combination_image)

outputs = [loss]
if isinstance(grads, (list, tuple)):
    outputs += grads
else:
    outputs.append(grads)

f_outputs = K.function([combination_image], outputs)
# Out:
# WARNING:tensorflow:Variable += will be deprecated. Use variable.assign_add if you want assignment to the variable value or 'x = x + y' if you want a new python Tensor object.

# %%
def eval_loss_and_grads(x):
    if K.image_data_format() == 'channels_first':
        x = x.reshape((1, 3, img_nrows, img_ncols))
    else:
        x = x.reshape((1, img_nrows, img_ncols, 3))
    outs = f_outputs([x])
    loss_value = outs[0]
    if len(outs[1:]) == 1:
        grad_values = outs[1].flatten().astype('float64')
    else:
        grad_values = np.array(outs[1:]).flatten().astype('float64')
    return loss_value, grad_values

# this Evaluator class makes it possible
# to compute loss and gradients in one pass
# while retrieving them via two separate functions,
# "loss" and "grads". This is done because scipy.optimize
# requires separate functions for loss and gradients,
# but computing them separately would be inefficient.


class Evaluator(object):

    def __init__(self):
        self.loss_value = None
        self.grads_values = None

    def loss(self, x):
        assert self.loss_value is None
        loss_value, grad_values = eval_loss_and_grads(x)
        self.loss_value = loss_value
        self.grad_values = grad_values
        return self.loss_value

    def grads(self, x):
        assert self.loss_value is not None
        grad_values = np.copy(self.grad_values)
        self.loss_value = None
        self.grad_values = None
        return grad_values

evaluator = Evaluator()

# %%
# run scipy-based optimization (L-BFGS) over the pixels of the generated image
# so as to minimize the neural style loss
x = preprocess_image(base_image_path)

for i in range(iterations):
    print('Start of iteration', i)
    start_time = time.time()
    x, min_val, info = fmin_l_bfgs_b(evaluator.loss, x.flatten(),
                                     fprime=evaluator.grads, maxfun=20)
    print('Current loss value:', min_val)
    # save current generated image
    img = deprocess_image(x.copy())
    fname = result_prefix + '_at_iteration_%d.png' % i
    im = array_to_img( img )
    im.save( fname )
    # save_img(fname, img)
    end_time = time.time()
    print('Image saved as', fname)
    print('Iteration %d completed in %ds' % (i, end_time - start_time))
# Out:
# Start of iteration 0
# Current loss value: 1485240000.0
# Image saved as /tmp/cat_monet_at_iteration_0.png
# Iteration 0 completed in 7s
# Start of iteration 1
# Current loss value: 816036900.0
# Image saved as /tmp/cat_monet_at_iteration_1.png
# Iteration 1 completed in 5s
# Start of iteration 2
# Current loss value: 632805000.0
# Image saved as /tmp/cat_monet_at_iteration_2.png
# Iteration 2 completed in 5s
# Start of iteration 3
# Current loss value: 557075300.0
# Image saved as /tmp/cat_monet_at_iteration_3.png
# Iteration 3 completed in 5s
# Start of iteration 4
# Current loss value: 510757800.0
# Image saved as /tmp/cat_monet_at_iteration_4.png
# Iteration 4 completed in 6s
# Start of iteration 5
# Current loss value: 480219650.0
# Image saved as /tmp/cat_monet_at_iteration_5.png
# Iteration 5 completed in 5s
# Start of iteration 6
# Current loss value: 458021860.0
# Image saved as /tmp/cat_monet_at_iteration_6.png
# Iteration 6 completed in 6s
# Start of iteration 7
# Current loss value: 438713200.0
# Image saved as /tmp/cat_monet_at_iteration_7.png
# Iteration 7 completed in 5s
# Start of iteration 8
# Current loss value: 423146500.0
# Image saved as /tmp/cat_monet_at_iteration_8.png
# Iteration 8 completed in 6s
# Start of iteration 9
# Current loss value: 410972670.0
# Image saved as /tmp/cat_monet_at_iteration_9.png
# Iteration 9 completed in 6s
# Start of iteration 10
# Current loss value: 400944900.0
# Image saved as /tmp/cat_monet_at_iteration_10.png
# Iteration 10 completed in 5s
# Start of iteration 11
# Current loss value: 391082180.0
# Image saved as /tmp/cat_monet_at_iteration_11.png
# Iteration 11 completed in 4s
# Start of iteration 12
# Current loss value: 382270340.0
# Image saved as /tmp/cat_monet_at_iteration_12.png
# Iteration 12 completed in 3s
# Start of iteration 13
# Current loss value: 375516350.0
# Image saved as /tmp/cat_monet_at_iteration_13.png
# Iteration 13 completed in 5s
# Start of iteration 14
# Current loss value: 368860860.0
# Image saved as /tmp/cat_monet_at_iteration_14.png
# Iteration 14 completed in 5s
# Start of iteration 15
# Current loss value: 363205860.0
# Image saved as /tmp/cat_monet_at_iteration_15.png
# Iteration 15 completed in 5s
# Start of iteration 16
# Current loss value: 357921920.0
# Image saved as /tmp/cat_monet_at_iteration_16.png
# Iteration 16 completed in 6s
# Start of iteration 17
# Current loss value: 352593630.0
# Image saved as /tmp/cat_monet_at_iteration_17.png
# Iteration 17 completed in 6s
# Start of iteration 18
# Current loss value: 347944480.0
# Image saved as /tmp/cat_monet_at_iteration_18.png
# Iteration 18 completed in 5s
# Start of iteration 19
# Current loss value: 343656700.0
# Image saved as /tmp/cat_monet_at_iteration_19.png
# Iteration 19 completed in 5s
# Start of iteration 20
# Current loss value: 339523460.0
# Image saved as /tmp/cat_monet_at_iteration_20.png
# Iteration 20 completed in 5s
# Start of iteration 21
# Current loss value: 335273400.0
# Image saved as /tmp/cat_monet_at_iteration_21.png
# Iteration 21 completed in 5s
# Start of iteration 22
# Current loss value: 331181250.0
# Image saved as /tmp/cat_monet_at_iteration_22.png
# Iteration 22 completed in 5s
# Start of iteration 23
# Current loss value: 327185760.0
# Image saved as /tmp/cat_monet_at_iteration_23.png
# Iteration 23 completed in 5s
# Start of iteration 24
# Current loss value: 323605540.0
# Image saved as /tmp/cat_monet_at_iteration_24.png
# Iteration 24 completed in 5s
# Start of iteration 25
# Current loss value: 320296600.0
# Image saved as /tmp/cat_monet_at_iteration_25.png
# Iteration 25 completed in 6s
# Start of iteration 26
# Current loss value: 317572380.0
# Image saved as /tmp/cat_monet_at_iteration_26.png
# Iteration 26 completed in 6s
# Start of iteration 27
# Current loss value: 314793730.0
# Image saved as /tmp/cat_monet_at_iteration_27.png
# Iteration 27 completed in 5s
# Start of iteration 28
# Current loss value: 312102050.0
# Image saved as /tmp/cat_monet_at_iteration_28.png
# Iteration 28 completed in 5s
# Start of iteration 29
# Current loss value: 309354080.0
# Image saved as /tmp/cat_monet_at_iteration_29.png
# Iteration 29 completed in 5s
# Start of iteration 30
# Current loss value: 307181700.0
# Image saved as /tmp/cat_monet_at_iteration_30.png
# Iteration 30 completed in 5s
# Start of iteration 31
# Current loss value: 305013440.0
# Image saved as /tmp/cat_monet_at_iteration_31.png
# Iteration 31 completed in 5s
# Start of iteration 32
# Current loss value: 303088700.0
# Image saved as /tmp/cat_monet_at_iteration_32.png
# Iteration 32 completed in 5s
# Start of iteration 33
# Current loss value: 300783300.0
# Image saved as /tmp/cat_monet_at_iteration_33.png
# Iteration 33 completed in 5s
# Start of iteration 34
# Current loss value: 298757900.0
# Image saved as /tmp/cat_monet_at_iteration_34.png
# Iteration 34 completed in 6s
# Start of iteration 35
# Current loss value: 297033540.0
# Image saved as /tmp/cat_monet_at_iteration_35.png
# Iteration 35 completed in 4s
# Start of iteration 36
# Current loss value: 294648640.0
# Image saved as /tmp/cat_monet_at_iteration_36.png
# Iteration 36 completed in 6s
# Start of iteration 37
# Current loss value: 293005600.0
# Image saved as /tmp/cat_monet_at_iteration_37.png
# Iteration 37 completed in 5s
# Start of iteration 38
# Current loss value: 291339330.0
# Image saved as /tmp/cat_monet_at_iteration_38.png
# Iteration 38 completed in 6s
# Start of iteration 39
# Current loss value: 289449120.0
# Image saved as /tmp/cat_monet_at_iteration_39.png
# Iteration 39 completed in 5s
# Start of iteration 40
# Current loss value: 287797380.0
# Image saved as /tmp/cat_monet_at_iteration_40.png
# Iteration 40 completed in 6s
# Start of iteration 41
# Current loss value: 286425920.0
# Image saved as /tmp/cat_monet_at_iteration_41.png
# Iteration 41 completed in 5s
# Start of iteration 42
# Current loss value: 285052380.0
# Image saved as /tmp/cat_monet_at_iteration_42.png
# Iteration 42 completed in 6s
# Start of iteration 43
# Current loss value: 283346370.0
# Image saved as /tmp/cat_monet_at_iteration_43.png
# Iteration 43 completed in 6s
# Start of iteration 44
# Current loss value: 282060030.0
# Image saved as /tmp/cat_monet_at_iteration_44.png
# Iteration 44 completed in 5s
# Start of iteration 45
# Current loss value: 280780060.0
# Image saved as /tmp/cat_monet_at_iteration_45.png
# Iteration 45 completed in 5s
# Start of iteration 46
# Current loss value: 279400960.0
# Image saved as /tmp/cat_monet_at_iteration_46.png
# Iteration 46 completed in 6s
# Start of iteration 47
# Current loss value: 278159360.0
# Image saved as /tmp/cat_monet_at_iteration_47.png
# Iteration 47 completed in 3s
# Start of iteration 48
# Current loss value: 276975200.0
# Image saved as /tmp/cat_monet_at_iteration_48.png
# Iteration 48 completed in 7s
# Start of iteration 49
# Current loss value: 275845380.0
# Image saved as /tmp/cat_monet_at_iteration_49.png
# Iteration 49 completed in 6s
# Start of iteration 50
# Current loss value: 274796860.0
# Image saved as /tmp/cat_monet_at_iteration_50.png
# Iteration 50 completed in 6s
# Start of iteration 51
# Current loss value: 273791740.0
# Image saved as /tmp/cat_monet_at_iteration_51.png
# Iteration 51 completed in 5s
# Start of iteration 52
# Current loss value: 272648030.0
# Image saved as /tmp/cat_monet_at_iteration_52.png
# Iteration 52 completed in 5s
# Start of iteration 53
# Current loss value: 271456260.0
# Image saved as /tmp/cat_monet_at_iteration_53.png
# Iteration 53 completed in 5s
# Start of iteration 54
# Current loss value: 270033200.0
# Image saved as /tmp/cat_monet_at_iteration_54.png
# Iteration 54 completed in 5s
# Start of iteration 55
# Current loss value: 268755360.0
# Image saved as /tmp/cat_monet_at_iteration_55.png
# Iteration 55 completed in 5s
# Start of iteration 56
# Current loss value: 267693180.0
# Image saved as /tmp/cat_monet_at_iteration_56.png
# Iteration 56 completed in 5s
# Start of iteration 57
# Current loss value: 266664200.0
# Image saved as /tmp/cat_monet_at_iteration_57.png
# Iteration 57 completed in 4s
# Start of iteration 58
# Current loss value: 265743300.0
# Image saved as /tmp/cat_monet_at_iteration_58.png
# Iteration 58 completed in 5s
# Start of iteration 59
# Current loss value: 264834370.0
# Image saved as /tmp/cat_monet_at_iteration_59.png
# Iteration 59 completed in 5s
# Start of iteration 60
# Current loss value: 264154640.0
# Image saved as /tmp/cat_monet_at_iteration_60.png
# Iteration 60 completed in 5s
# Start of iteration 61
# Current loss value: 263182350.0
# Image saved as /tmp/cat_monet_at_iteration_61.png
# Iteration 61 completed in 4s
# Start of iteration 62
# Current loss value: 262375650.0
# Image saved as /tmp/cat_monet_at_iteration_62.png
# Iteration 62 completed in 5s
# Start of iteration 63
# Current loss value: 261267330.0
# Image saved as /tmp/cat_monet_at_iteration_63.png
# Iteration 63 completed in 5s
# Start of iteration 64
# Current loss value: 260244700.0
# Image saved as /tmp/cat_monet_at_iteration_64.png
# Iteration 64 completed in 4s
# Start of iteration 65
# Current loss value: 259436460.0
# Image saved as /tmp/cat_monet_at_iteration_65.png
# Iteration 65 completed in 5s
# Start of iteration 66
# Current loss value: 258734770.0
# Image saved as /tmp/cat_monet_at_iteration_66.png
# Iteration 66 completed in 5s
# Start of iteration 67
# Current loss value: 258086850.0
# Image saved as /tmp/cat_monet_at_iteration_67.png
# Iteration 67 completed in 6s
# Start of iteration 68
# Current loss value: 257499410.0
# Image saved as /tmp/cat_monet_at_iteration_68.png
# Iteration 68 completed in 5s
# Start of iteration 69
# Current loss value: 256951470.0
# Image saved as /tmp/cat_monet_at_iteration_69.png
# Iteration 69 completed in 6s
# Start of iteration 70
# Current loss value: 256378910.0
# Image saved as /tmp/cat_monet_at_iteration_70.png
# Iteration 70 completed in 5s
# Start of iteration 71
# Current loss value: 255621890.0
# Image saved as /tmp/cat_monet_at_iteration_71.png
# Iteration 71 completed in 5s
# Start of iteration 72
# Current loss value: 254904960.0
# Image saved as /tmp/cat_monet_at_iteration_72.png
# Iteration 72 completed in 4s
# Start of iteration 73
# Current loss value: 254373040.0
# Image saved as /tmp/cat_monet_at_iteration_73.png
# Iteration 73 completed in 5s
# Start of iteration 74
# Current loss value: 253811650.0
# Image saved as /tmp/cat_monet_at_iteration_74.png
# Iteration 74 completed in 4s
# Start of iteration 75
# Current loss value: 253294600.0
# Image saved as /tmp/cat_monet_at_iteration_75.png
# Iteration 75 completed in 3s
# Start of iteration 76
# Current loss value: 252791680.0
# Image saved as /tmp/cat_monet_at_iteration_76.png
# Iteration 76 completed in 5s
# Start of iteration 77
# Current loss value: 252328750.0
# Image saved as /tmp/cat_monet_at_iteration_77.png
# Iteration 77 completed in 5s
# Start of iteration 78
# Current loss value: 251804800.0
# Image saved as /tmp/cat_monet_at_iteration_78.png
# Iteration 78 completed in 4s
# Start of iteration 79
# Current loss value: 251318530.0
# Image saved as /tmp/cat_monet_at_iteration_79.png
# Iteration 79 completed in 5s
# Start of iteration 80
# Current loss value: 250597340.0
# Image saved as /tmp/cat_monet_at_iteration_80.png
# Iteration 80 completed in 5s
# Start of iteration 81
# Current loss value: 250062300.0
# Image saved as /tmp/cat_monet_at_iteration_81.png
# Iteration 81 completed in 5s
# Start of iteration 82
# Current loss value: 249614050.0
# Image saved as /tmp/cat_monet_at_iteration_82.png
# Iteration 82 completed in 5s
# Start of iteration 83
# Current loss value: 249054300.0
# Image saved as /tmp/cat_monet_at_iteration_83.png
# Iteration 83 completed in 4s
# Start of iteration 84
# Current loss value: 248584350.0
# Image saved as /tmp/cat_monet_at_iteration_84.png
# Iteration 84 completed in 5s
# Start of iteration 85
# Current loss value: 248184480.0
# Image saved as /tmp/cat_monet_at_iteration_85.png
# Iteration 85 completed in 5s
# Start of iteration 86
# Current loss value: 247728220.0
# Image saved as /tmp/cat_monet_at_iteration_86.png
# Iteration 86 completed in 4s
# Start of iteration 87
# Current loss value: 247210560.0
# Image saved as /tmp/cat_monet_at_iteration_87.png
# Iteration 87 completed in 4s
# Start of iteration 88
# Current loss value: 246699970.0
# Image saved as /tmp/cat_monet_at_iteration_88.png
# Iteration 88 completed in 4s
# Start of iteration 89
# Current loss value: 246301810.0
# Image saved as /tmp/cat_monet_at_iteration_89.png
# Iteration 89 completed in 4s
# Start of iteration 90
# Current loss value: 245933920.0
# Image saved as /tmp/cat_monet_at_iteration_90.png
# Iteration 90 completed in 5s
# Start of iteration 91
# Current loss value: 245590670.0
# Image saved as /tmp/cat_monet_at_iteration_91.png
# Iteration 91 completed in 6s
# Start of iteration 92
# Current loss value: 245070720.0
# Image saved as /tmp/cat_monet_at_iteration_92.png
# Iteration 92 completed in 5s
# Start of iteration 93
# Current loss value: 244656670.0
# Image saved as /tmp/cat_monet_at_iteration_93.png
# Iteration 93 completed in 5s
# Start of iteration 94
# Current loss value: 244256100.0
# Image saved as /tmp/cat_monet_at_iteration_94.png
# Iteration 94 completed in 5s
# Start of iteration 95
# Current loss value: 243887060.0
# Image saved as /tmp/cat_monet_at_iteration_95.png
# Iteration 95 completed in 5s
# Start of iteration 96
# Current loss value: 243596660.0
# Image saved as /tmp/cat_monet_at_iteration_96.png
# Iteration 96 completed in 6s
# Start of iteration 97
# Current loss value: 243304690.0
# Image saved as /tmp/cat_monet_at_iteration_97.png
# Iteration 97 completed in 5s
# Start of iteration 98
# Current loss value: 243003410.0
# Image saved as /tmp/cat_monet_at_iteration_98.png
# Iteration 98 completed in 5s
# Start of iteration 99
# Current loss value: 242668660.0
# Image saved as /tmp/cat_monet_at_iteration_99.png
# Iteration 99 completed in 5s
# Start of iteration 100
# Current loss value: 242360930.0
# Image saved as /tmp/cat_monet_at_iteration_100.png
# Iteration 100 completed in 5s
# Start of iteration 101
# Current loss value: 241957890.0
# Image saved as /tmp/cat_monet_at_iteration_101.png
# Iteration 101 completed in 5s
# Start of iteration 102
# Current loss value: 241636640.0
# Image saved as /tmp/cat_monet_at_iteration_102.png
# Iteration 102 completed in 4s
# Start of iteration 103
# Current loss value: 241384590.0
# Image saved as /tmp/cat_monet_at_iteration_103.png
# Iteration 103 completed in 5s
# Start of iteration 104
# Current loss value: 241073380.0
# Image saved as /tmp/cat_monet_at_iteration_104.png
# Iteration 104 completed in 5s
# Start of iteration 105
# Current loss value: 240799950.0
# Image saved as /tmp/cat_monet_at_iteration_105.png
# Iteration 105 completed in 5s
# Start of iteration 106
# Current loss value: 240453310.0
# Image saved as /tmp/cat_monet_at_iteration_106.png
# Iteration 106 completed in 5s
# Start of iteration 107
# Current loss value: 240139870.0
# Image saved as /tmp/cat_monet_at_iteration_107.png
# Iteration 107 completed in 6s
# Start of iteration 108
# Current loss value: 239850930.0
# Image saved as /tmp/cat_monet_at_iteration_108.png
# Iteration 108 completed in 5s
# Start of iteration 109
# Current loss value: 239584000.0
# Image saved as /tmp/cat_monet_at_iteration_109.png
# Iteration 109 completed in 6s
# Start of iteration 110
# Current loss value: 239344100.0
# Image saved as /tmp/cat_monet_at_iteration_110.png
# Iteration 110 completed in 6s
# Start of iteration 111
# Current loss value: 239052830.0
# Image saved as /tmp/cat_monet_at_iteration_111.png
# Iteration 111 completed in 5s
# Start of iteration 112
# Current loss value: 238763650.0
# Image saved as /tmp/cat_monet_at_iteration_112.png
# Iteration 112 completed in 3s
# Start of iteration 113
# Current loss value: 238502270.0
# Image saved as /tmp/cat_monet_at_iteration_113.png
# Iteration 113 completed in 4s
# Start of iteration 114
# Current loss value: 238230050.0
# Image saved as /tmp/cat_monet_at_iteration_114.png
# Iteration 114 completed in 4s
# Start of iteration 115
# Current loss value: 237958940.0
# Image saved as /tmp/cat_monet_at_iteration_115.png
# Iteration 115 completed in 5s
# Start of iteration 116
# Current loss value: 237706270.0
# Image saved as /tmp/cat_monet_at_iteration_116.png
# Iteration 116 completed in 4s
# Start of iteration 117
# Current loss value: 237452450.0
# Image saved as /tmp/cat_monet_at_iteration_117.png
# Iteration 117 completed in 6s
# Start of iteration 118
# Current loss value: 237159100.0
# Image saved as /tmp/cat_monet_at_iteration_118.png
# Iteration 118 completed in 6s
# Start of iteration 119
# Current loss value: 236880930.0
# Image saved as /tmp/cat_monet_at_iteration_119.png
# Iteration 119 completed in 7s
# Start of iteration 120
# Current loss value: 236637580.0
# Image saved as /tmp/cat_monet_at_iteration_120.png
# Iteration 120 completed in 4s
# Start of iteration 121
# Current loss value: 236409890.0
# Image saved as /tmp/cat_monet_at_iteration_121.png
# Iteration 121 completed in 5s
# Start of iteration 122
# Current loss value: 236157810.0
# Image saved as /tmp/cat_monet_at_iteration_122.png
# Iteration 122 completed in 5s
# Start of iteration 123
# Current loss value: 235910370.0
# Image saved as /tmp/cat_monet_at_iteration_123.png
# Iteration 123 completed in 6s
# Start of iteration 124
# Current loss value: 235670300.0
# Image saved as /tmp/cat_monet_at_iteration_124.png
# Iteration 124 completed in 5s
# Start of iteration 125
# Current loss value: 235441570.0
# Image saved as /tmp/cat_monet_at_iteration_125.png
# Iteration 125 completed in 4s
# Start of iteration 126
# Current loss value: 235240960.0
# Image saved as /tmp/cat_monet_at_iteration_126.png
# Iteration 126 completed in 5s
# Start of iteration 127
# Current loss value: 235027940.0
# Image saved as /tmp/cat_monet_at_iteration_127.png
# Iteration 127 completed in 4s
# Start of iteration 128
# Current loss value: 234828900.0
# Image saved as /tmp/cat_monet_at_iteration_128.png
# Iteration 128 completed in 5s
# Start of iteration 129
# Current loss value: 234594220.0
# Image saved as /tmp/cat_monet_at_iteration_129.png
# Iteration 129 completed in 5s
# Start of iteration 130
# Current loss value: 234379800.0
# Image saved as /tmp/cat_monet_at_iteration_130.png
# Iteration 130 completed in 5s
# Start of iteration 131
# Current loss value: 234155580.0
# Image saved as /tmp/cat_monet_at_iteration_131.png
# Iteration 131 completed in 5s
# Start of iteration 132
# Current loss value: 233960350.0
# Image saved as /tmp/cat_monet_at_iteration_132.png
# Iteration 132 completed in 5s
# Start of iteration 133
# Current loss value: 233755100.0
# Image saved as /tmp/cat_monet_at_iteration_133.png
# Iteration 133 completed in 5s
# Start of iteration 134
# Current loss value: 233544030.0
# Image saved as /tmp/cat_monet_at_iteration_134.png
# Iteration 134 completed in 5s
# Start of iteration 135
# Current loss value: 233336320.0
# Image saved as /tmp/cat_monet_at_iteration_135.png
# Iteration 135 completed in 5s
# Start of iteration 136
# Current loss value: 233155230.0
# Image saved as /tmp/cat_monet_at_iteration_136.png
# Iteration 136 completed in 5s
# Start of iteration 137
# Current loss value: 232912420.0
# Image saved as /tmp/cat_monet_at_iteration_137.png
# Iteration 137 completed in 5s
# Start of iteration 138
# Current loss value: 232673540.0
# Image saved as /tmp/cat_monet_at_iteration_138.png
# Iteration 138 completed in 5s
# Start of iteration 139
# Current loss value: 232475940.0
# Image saved as /tmp/cat_monet_at_iteration_139.png
# Iteration 139 completed in 5s
# Start of iteration 140
# Current loss value: 232265710.0
# Image saved as /tmp/cat_monet_at_iteration_140.png
# Iteration 140 completed in 5s
# Start of iteration 141
# Current loss value: 232086560.0
# Image saved as /tmp/cat_monet_at_iteration_141.png
# Iteration 141 completed in 3s
# Start of iteration 142
# Current loss value: 231932960.0
# Image saved as /tmp/cat_monet_at_iteration_142.png
# Iteration 142 completed in 5s
# Start of iteration 143
# Current loss value: 231739950.0
# Image saved as /tmp/cat_monet_at_iteration_143.png
# Iteration 143 completed in 6s
# Start of iteration 144
# Current loss value: 231556050.0
# Image saved as /tmp/cat_monet_at_iteration_144.png
# Iteration 144 completed in 4s
# Start of iteration 145
# Current loss value: 231384050.0
# Image saved as /tmp/cat_monet_at_iteration_145.png
# Iteration 145 completed in 5s
# Start of iteration 146
# Current loss value: 231201860.0
# Image saved as /tmp/cat_monet_at_iteration_146.png
# Iteration 146 completed in 5s
# Start of iteration 147
# Current loss value: 231013800.0
# Image saved as /tmp/cat_monet_at_iteration_147.png
# Iteration 147 completed in 5s
# Start of iteration 148
# Current loss value: 230835000.0
# Image saved as /tmp/cat_monet_at_iteration_148.png
# Iteration 148 completed in 5s
# Start of iteration 149
# Current loss value: 230668050.0
# Image saved as /tmp/cat_monet_at_iteration_149.png
# Iteration 149 completed in 5s
# Start of iteration 150
# Current loss value: 230512700.0
# Image saved as /tmp/cat_monet_at_iteration_150.png
# Iteration 150 completed in 5s
# Start of iteration 151
# Current loss value: 230361310.0
# Image saved as /tmp/cat_monet_at_iteration_151.png
# Iteration 151 completed in 6s
# Start of iteration 152
# Current loss value: 230215800.0
# Image saved as /tmp/cat_monet_at_iteration_152.png
# Iteration 152 completed in 5s
# Start of iteration 153
# Current loss value: 230049330.0
# Image saved as /tmp/cat_monet_at_iteration_153.png
# Iteration 153 completed in 5s
# Start of iteration 154
# Current loss value: 229894140.0
# Image saved as /tmp/cat_monet_at_iteration_154.png
# Iteration 154 completed in 4s
# Start of iteration 155
# Current loss value: 229745700.0
# Image saved as /tmp/cat_monet_at_iteration_155.png
# Iteration 155 completed in 5s
# Start of iteration 156
# Current loss value: 229587550.0
# Image saved as /tmp/cat_monet_at_iteration_156.png
# Iteration 156 completed in 6s
# Start of iteration 157
# Current loss value: 229428670.0
# Image saved as /tmp/cat_monet_at_iteration_157.png
# Iteration 157 completed in 6s
# Start of iteration 158
# Current loss value: 229241820.0
# Image saved as /tmp/cat_monet_at_iteration_158.png
# Iteration 158 completed in 5s
# Start of iteration 159
# Current loss value: 229068700.0
# Image saved as /tmp/cat_monet_at_iteration_159.png
# Iteration 159 completed in 5s
# Start of iteration 160
# Current loss value: 228870560.0
# Image saved as /tmp/cat_monet_at_iteration_160.png
# Iteration 160 completed in 5s
# Start of iteration 161
# Current loss value: 228708750.0
# Image saved as /tmp/cat_monet_at_iteration_161.png
# Iteration 161 completed in 6s
# Start of iteration 162
# Current loss value: 228578200.0
# Image saved as /tmp/cat_monet_at_iteration_162.png
# Iteration 162 completed in 5s
# Start of iteration 163
# Current loss value: 228419550.0
# Image saved as /tmp/cat_monet_at_iteration_163.png
# Iteration 163 completed in 6s
# Start of iteration 164
# Current loss value: 228237000.0
# Image saved as /tmp/cat_monet_at_iteration_164.png
# Iteration 164 completed in 4s
# Start of iteration 165
# Current loss value: 228089890.0
# Image saved as /tmp/cat_monet_at_iteration_165.png
# Iteration 165 completed in 6s
# Start of iteration 166
# Current loss value: 227942830.0
# Image saved as /tmp/cat_monet_at_iteration_166.png
# Iteration 166 completed in 4s
# Start of iteration 167
# Current loss value: 227768220.0
# Image saved as /tmp/cat_monet_at_iteration_167.png
# Iteration 167 completed in 6s
# Start of iteration 168
# Current loss value: 227615680.0
# Image saved as /tmp/cat_monet_at_iteration_168.png
# Iteration 168 completed in 6s
# Start of iteration 169
# Current loss value: 227445010.0
# Image saved as /tmp/cat_monet_at_iteration_169.png
# Iteration 169 completed in 5s
# Start of iteration 170
# Current loss value: 227256800.0
# Image saved as /tmp/cat_monet_at_iteration_170.png
# Iteration 170 completed in 5s
# Start of iteration 171
# Current loss value: 227072290.0
# Image saved as /tmp/cat_monet_at_iteration_171.png
# Iteration 171 completed in 6s
# Start of iteration 172
# Current loss value: 226851870.0
# Image saved as /tmp/cat_monet_at_iteration_172.png
# Iteration 172 completed in 5s
# Start of iteration 173
# Current loss value: 226706620.0
# Image saved as /tmp/cat_monet_at_iteration_173.png
# Iteration 173 completed in 6s
# Start of iteration 174
# Current loss value: 226583260.0
# Image saved as /tmp/cat_monet_at_iteration_174.png
# Iteration 174 completed in 5s
# Start of iteration 175
# Current loss value: 226416590.0
# Image saved as /tmp/cat_monet_at_iteration_175.png
# Iteration 175 completed in 5s
# Start of iteration 176
# Current loss value: 226251400.0
# Image saved as /tmp/cat_monet_at_iteration_176.png
# Iteration 176 completed in 5s
# Start of iteration 177
# Current loss value: 226097420.0
# Image saved as /tmp/cat_monet_at_iteration_177.png
# Iteration 177 completed in 4s
# Start of iteration 178
# Current loss value: 225947680.0
# Image saved as /tmp/cat_monet_at_iteration_178.png
# Iteration 178 completed in 6s
# Start of iteration 179
# Current loss value: 225807970.0
# Image saved as /tmp/cat_monet_at_iteration_179.png
# Iteration 179 completed in 3s
# Start of iteration 180
# Current loss value: 225635100.0
# Image saved as /tmp/cat_monet_at_iteration_180.png
# Iteration 180 completed in 4s
# Start of iteration 181
# Current loss value: 225516480.0
# Image saved as /tmp/cat_monet_at_iteration_181.png
# Iteration 181 completed in 5s
# Start of iteration 182
# Current loss value: 225395570.0
# Image saved as /tmp/cat_monet_at_iteration_182.png
# Iteration 182 completed in 5s
# Start of iteration 183
# Current loss value: 225274930.0
# Image saved as /tmp/cat_monet_at_iteration_183.png
# Iteration 183 completed in 6s
# Start of iteration 184
# Current loss value: 225165180.0
# Image saved as /tmp/cat_monet_at_iteration_184.png
# Iteration 184 completed in 4s
# Start of iteration 185
# Current loss value: 224965150.0
# Image saved as /tmp/cat_monet_at_iteration_185.png
# Iteration 185 completed in 5s
# Start of iteration 186
# Current loss value: 224754430.0
# Image saved as /tmp/cat_monet_at_iteration_186.png
# Iteration 186 completed in 5s
# Start of iteration 187
# Current loss value: 224607780.0
# Image saved as /tmp/cat_monet_at_iteration_187.png
# Iteration 187 completed in 5s
# Start of iteration 188
# Current loss value: 224464980.0
# Image saved as /tmp/cat_monet_at_iteration_188.png
# Iteration 188 completed in 5s
# Start of iteration 189
# Current loss value: 224353340.0
# Image saved as /tmp/cat_monet_at_iteration_189.png
# Iteration 189 completed in 5s
# Start of iteration 190
# Current loss value: 224231020.0
# Image saved as /tmp/cat_monet_at_iteration_190.png
# Iteration 190 completed in 5s
# Start of iteration 191
# Current loss value: 224114340.0
# Image saved as /tmp/cat_monet_at_iteration_191.png
# Iteration 191 completed in 6s
# Start of iteration 192
# Current loss value: 223975620.0
# Image saved as /tmp/cat_monet_at_iteration_192.png
# Iteration 192 completed in 4s
# Start of iteration 193
# Current loss value: 223861100.0
# Image saved as /tmp/cat_monet_at_iteration_193.png
# Iteration 193 completed in 5s
# Start of iteration 194
# Current loss value: 223728600.0
# Image saved as /tmp/cat_monet_at_iteration_194.png
# Iteration 194 completed in 4s
# Start of iteration 195
# Current loss value: 223600030.0
# Image saved as /tmp/cat_monet_at_iteration_195.png
# Iteration 195 completed in 5s
# Start of iteration 196
# Current loss value: 223508480.0
# Image saved as /tmp/cat_monet_at_iteration_196.png
# Iteration 196 completed in 6s
# Start of iteration 197
# Current loss value: 223382080.0
# Image saved as /tmp/cat_monet_at_iteration_197.png
# Iteration 197 completed in 4s
# Start of iteration 198
# Current loss value: 223275920.0
# Image saved as /tmp/cat_monet_at_iteration_198.png
# Iteration 198 completed in 5s
# Start of iteration 199
# Current loss value: 223159520.0
# Image saved as /tmp/cat_monet_at_iteration_199.png
# Iteration 199 completed in 5s
